# %% [markdown]
# # Execution Pipeline

# %% [markdown]
# ### Compilate and run a C script that create a father process and a child process

# %%
# %%bash
# # man fork
# # fork() for create a Process
# #
# gcc Scripts/proceso.c -o executable-files/procesoBin
# ./executable-files/procesoBin
# Out:
# hola soy padre
# hola soy hijo

# %% [markdown]
# ### Compilate a C script that create a process, let's see the resources monitor in linux using "htop" command

# %%
# %%bash
# gcc Scripts/BigCharge.c -o executable-files/BigChargeBin -lm
# ./executable-files/BigChargeBin

# %%
# %%bash
# man wait
# Out:
# WAIT(2)                    Linux Programmer's Manual                   WAIT(2)
#
# NAME
#        wait, waitpid, waitid - wait for process to change state
#
# SYNOPSIS
#        #include <sys/types.h>
#        #include <sys/wait.h>
#
#        pid_t wait(int *wstatus);
#
#        pid_t waitpid(pid_t pid, int *wstatus, int options);
#
#        int waitid(idtype_t idtype, id_t id, siginfo_t *infop, int options);
#                        /* This is the glibc and POSIX interface; see
#                           NOTES for information on the raw system call. */
#
#    Feature Test Macro Requirements for glibc (see feature_test_macros(7)):
#
#        waitid():
#            Since glibc 2.26: _XOPEN_SOURCE >= 500 ||
#                _POSIX_C_SOURCE >= 200809L
#            Glibc 2.25 and earlier:
#                _XOPEN_SOURCE
#                    || /* Since glibc 2.12: */ _POSIX_C_SOURCE >= 200809L
#                    || /* Glibc versions <= 2.19: */ _BSD_SOURCE
#
# DESCRIPTION
# ...

# %% [markdown]
# ### Compilate and run a C script that create a father process and a child process that calculate PI constant using Gregory-Leibniz Series and testing the decimal precision with several n numbers

# %%
# %%bash
# gcc Scripts/pi.c -o executable-files/piCalc -lm
# ./executable-files/piCalc
#
# # 3.14159265359 -> Google answer
# # 3.141592653489809341266e+00 -> using Gregory-Leibniz Series with n = 2e10
# # 3.141592653569798259533e+00 -> using Gregory-Leibniz Series with n = 1e11
# Out:
# 3.141592653569798259533e+00

# %% [markdown]
# ## Wednesday Homework
#
# - Linux Device 3 -> drivers 3 -> Diagrama bloques -> kernel
